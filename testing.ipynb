# %%
import numpy as np

# %%
a = np.array([1,2])

# %%
a[:,1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a[:,1]
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
len(np.shape(a))
# Out:
# 1

# %%
inflection_points = [1,2,3]

# %%
if not isinstance(inflection_points, np.ndarray) and isinstance(inflection_points, list):
    inflection_points = np.array(inflection_points)

# %%
type(inflection_points)
# Out:
# numpy.ndarray

# %%
inflection_points
# Out:
# array([1, 2, 3])
